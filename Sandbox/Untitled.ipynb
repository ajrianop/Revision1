# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Definir el path al documento CSV
file_path = 'datasets/forecasting_database.csv'

# Leer el documento CSV
df = pd.read_csv(file_path)

#Imprimiendo las 5 primeras filas 
df.head()
# Out:
#          Date  Campaign ID     Keyword      Cost      CPC
# 0  2021-12-27   1646440648  TvCO hogar  14480118  4094.04
# 1  2021-12-13   1646440648  TvCO hogar  13511283  3212.01
# 2  2021-12-09   1646440648  TvCO hogar  13058381  3281.31
# 3  2021-12-16   1646440648  TvCO hogar  11300242  3181.48
# 4  2021-12-10   1646440648  TvCO hogar  10832131  4111.83

# %%
# Observando el tipo de información del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24990 entries, 0 to 24989
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         24990 non-null  object
#  1   Campaign ID  24990 non-null  int64
#  2   Keyword      24990 non-null  object
#  3   Cost         24990 non-null  int64
#  4   CPC          24990 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 976.3+ KB

# %% [markdown]
# La definición de las variables son las siguientes:
# * `Date`: Fecha de revisión
# * `Campaign ID`: ID de la campaña
# * `Keyword`: Palabra clave de la campaña
# * `Cost`: inversion en la campaña de anuncios (CampaingID)
# * `CPC`: Costo por click

# %%
sorted_df = df.sort_values(by='Date', ascending=True)
sorted_df
# Out:
#              Date  Campaign ID                      Keyword     Cost      CPC
# 24540  2021-01-01   1646440648       paquetes de TvCO+hogar -1285122   194.10
# 24141  2021-01-01   1646642053                internet fijo -1284213   301.00
# 22797  2021-01-01   1646440683        internet TvCO precios -1284131   331.10
# 11132  2021-01-01   1646440648                   TvCO hogar -1152028   212.11
# 12693  2021-01-01   1646440666                      TvCO tv -1222234   129.00
# ...           ...          ...                          ...      ...      ...
# 9645   2021-12-31   1646440683                      TvCObox -1285430    24.00
# 5648   2021-12-31  14832003666    planes TvCO hogar precios -1233314   831.13
# 6472   2021-12-31   1646440683      triple play TvCO planes -1280011  2211.00
# 7139   2021-12-31   1646440683  +planes +triple +play +TvCO -1281121  2193.00
# 8625   2021-12-31   1646440683       TvCO television planes -1283114  1814.00
#
# [24990 rows x 5 columns]

# %%
df.describe()
# Out:
#         Campaign ID          Cost           CPC
# count  2.499000e+04  2.499000e+04  24990.000000
# mean   4.330822e+09 -1.170046e+06   1467.915930
# std    4.900389e+09  4.881327e+05   1293.781346
# min    1.646441e+09 -1.285513e+06      1.000000
# 25%    1.646441e+09 -1.282312e+06    802.105000
# 50%    1.646441e+09 -1.238153e+06   1219.000000
# 75%    1.801436e+09 -1.218811e+06   2102.115000
# max    1.541254e+10  1.448012e+07  33430.330000

# %%
df['Date'].unique()
# Out:
# array(['2021-12-27', '2021-12-13', '2021-12-09', '2021-12-16',
#        '2021-12-10', '2021-09-06', '2021-12-14', '2021-12-15',
#        '2021-12-06', '2021-12-07', '2021-12-03', '2021-09-13',
#        '2021-09-08', '2021-09-01', '2021-12-20', '2021-09-07',
#        '2021-09-15', '2021-09-09', '2021-09-14', '2021-12-11',
#        '2021-12-02', '2021-09-02', '2021-12-17', '2021-12-01',
#        '2021-09-30', '2021-11-30', '2021-11-16', '2021-11-08',
#        '2021-10-27', '2021-09-03', '2021-10-28', '2021-12-04',
#        '2021-09-10', '2021-11-10', '2021-11-09', '2021-11-17',
#        '2021-10-26', '2021-10-04', '2021-12-12', '2021-09-20',
#        '2021-12-21', '2021-10-06', '2021-11-18', '2021-10-05',
#        '2021-11-02', '2021-12-05', '2021-11-11', '2021-12-22',
#        '2021-10-11', '2021-11-04', '2021-12-28', '2021-09-16',
#        '2021-09-04', '2021-10-08', '2021-09-29', '2021-10-19',
#        '2021-11-05', '2021-11-12', '2021-12-08', '2021-11-19',
# ...

# %%
len(df['Date'].unique())
# Out:
# 365
